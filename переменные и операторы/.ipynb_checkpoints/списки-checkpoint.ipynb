# %%
for x in 1,2,7,4,5:
    print(x)

# %%
_list = [1,2,7,4,5]

# %%
print(_list)

# %%
for x in _list:
    print(x)

# %%
for x in r,g,b:
    print(x)

# %%
r="red"
g="green"
b="blue"

# %%
colors = [r,g,b]

# %%
while colors:
    print(colors)

# %%
colors = False

# %%
x = 25+ int(input())

# %%
print(x)
