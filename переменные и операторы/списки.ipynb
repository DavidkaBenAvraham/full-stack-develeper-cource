# %%
for x in 1,2,7,4,5:
    print(x)
# Out:
# 1
# 2
# 7
# 4
# 5

# %%
def get_number(n):
    return n**n

# %%
for x in 1,'some test', True, get_number(5):
    print(x)
# Out:
# 1
# some test
# True
# 3125

# %%
_list = [1,2,7,4,5]

# %%
print(_list)

# %%
for x in _list:
    print(x)

# %%
for x in r,g,b:
    print(x)

# %%
r="red"
g="green"
b="blue"

# %%
colors = [r,g,b]

# %%
while colors:
    print(colors)

# %%
colors = False

# %%
x = 25+ int(input())

# %%
print(x)
