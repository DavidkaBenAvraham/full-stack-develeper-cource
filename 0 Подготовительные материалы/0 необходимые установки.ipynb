# %% [markdown]
# ### установки
#  <a href='https://ninite.com/7zip-chrome-filezilla-googledrivefordesktop-inkscape-keepass2-libreoffice-notepadplusplus-paint.net-vscode/'>
#      Софт, который будет использоваться в течение курса </a>
#      <ul>
#     <li>7zip</li>
#     <li>chrome</li>
#     <li>filezilla</li>
#     <li>googledrivefordesktop</li>
#     <li>inkscape</li>
#     <li>libreoffice</li>
#     <li>notepadplusplus</li>
#     <li>paint.net</li>
#     <li>vscode</li>
#    </ul>
#     <li><a href='https://www.anaconda.com/'>Anaconda</a><br>
#     <li><a href='https://www.anaconda.com/'>Visual studio community edition</a>
#     <li><a href='https://dbeaver.io/'>DBeaver community edition</a>
#     ---
#     <li><a href='https://www.apachefriends.org/'>XAMPP</a>

# %% [markdown]
# ### В анаконде есть много, но добавим еще модулей :

# %%
'''
 ВНИМАНИЕ!
 Запуск функции install_modules() приведет к установке пакетов.
 Нет необходимости повторять установки нескоьлко раз на одной машине
'''
def install_modules():
    # !pip install certifi
    # !pip install tornad
    # !pip install cryptography
    # !pip install decorator
    # !pip install APScheduler
    # !pip install pytz
    # !pip install selenium
    # !pip install selenium-wire
    # !pip install kora

    # !pip install google
    # !pip install oauth2client 
    # !pip install df2gspread
    # !pip install google-auth-httplib2



    # !pip install aliyun-python-sdk-core-v3
    # !pip install aliexpress-sdk
    # !pip install pyautogui
    # !pip install gspread 

    # !pip install jupyterlab
    # !pip install install attrs
    # !conda install -c conda-forge jupyterlab-drawio
    
install_modules()
