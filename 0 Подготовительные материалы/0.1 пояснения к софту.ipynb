# %%
from IPython.display import YouTubeVideo
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# > # Знакомство с софтом

# %% [markdown]
# > ### Jupiter
# <b><a href='https://colab.research.google.com/drive/19HU4MBauq2OY0lYsT9KHsGGHbGHPV6uJ'>On Google colab
#     >> ### video about Jupiter

# %%
out = widgets.Output(layout={'border': '3px solid black'})
out.append_stdout('Output appended with append_stdout')
out.append_display_data(YouTubeVideo('Uyeu3m3BSXw'))
out

# %% [markdown]
# > ### Keypass
# KeePass is a free open source password manager, which helps you to manage your passwords in a secure way. You can store all your passwords in one database, which is locked with a master key. So you only have to remember one single master key to unlock the whole database. Database files are encrypted using the best and most secure encryption algorithms currently known (AES-256, ChaCha20 and Twofish). For more information, see the <b><a href='https://keepass.info/'>features page.</a><b>
#     >> ### video about Keypass

# %%
out = widgets.Output(layout={'border': '3px solid black'})
out.append_stdout('Output appended with append_stdout')
out.append_display_data(YouTubeVideo('GyuVLIbmI5U'))
out
# Out:
# Output(layout=Layout(border='3px solid black'), outputs=({'output_type': 'stream', 'name': 'stdout', 'text': '…

# %% [markdown]
# ---

# %% [markdown]
# > ### Paint.NET
# Paint.NET is image and photo editing software for PCs that run Windows. It features an intuitive and innovative user interface with support for layers, unlimited undo, special effects, and a wide variety of useful and powerful tools. An active and growing online community provides friendly help, tutorials, and plugins.For more information, see the <b><a href='https://www.getpaint.net/'>features page.</a></b>

# %%
out = widgets.Output(layout={'border': '3px solid black'})
out.append_stdout('Output appended with append_stdout')
out.append_display_data(YouTubeVideo('fsL935G0VMM'))
out
# Out:
# Output(layout=Layout(border='3px solid black'), outputs=({'output_type': 'stream', 'name': 'stdout', 'text': '…

# %% [markdown]
# > ### FileZilla
# The FileZilla software program is a free-to-use (open source) FTP utility, allowing a user to transfer files from a local computer to a remote computer. FileZilla is available as a client version and a server version. For more information, see the <b><a href='https://filezilla-project.org/'>features page.</a></b>

# %%
out = widgets.Output(layout={'border': '3px solid black'})
out.append_stdout('Output appended with append_stdout')
out.append_display_data(YouTubeVideo('adxmlHDim6c'))
out
# Out:
# Output(layout=Layout(border='3px solid black'), outputs=({'output_type': 'stream', 'name': 'stdout', 'text': '…

# %% [markdown]
# > ### InkScape
# Inkscape is a Free and open source vector graphics editor for GNU/Linux, Windows and macOS. It offers a rich set of features and is widely used for both artistic and technical illustrations such as cartoons, clip art, logos, typography, diagramming and flowcharting. It uses vector graphics to allow for sharp printouts and renderings at unlimited resolution and is not bound to a fixed number of pixels like raster graphics. Inkscape uses the standardized SVG file format as its main format, which is supported by many other applications including web browsers.

# %%
out = widgets.Output(layout={'border': '3px solid black'})
out.append_stdout('Output appended with append_stdout')
out.append_display_data(YouTubeVideo('pVwyBiSka64'))
out
# Out:
# Output(layout=Layout(border='3px solid black'), outputs=({'output_type': 'stream', 'name': 'stdout', 'text': '…

# %% [markdown]
# > ### Diagrams.net
# diagrams.net/draw.io is an open source technology stack for building diagramming applications, and the world’s most widely used browser-based end-user diagramming software.<b><a href='diagrams.net/draw.io'>features page.</a></b>

# %%
out = widgets.Output(layout={'border': '3px solid black'})
out.append_stdout('Output appended with append_stdout')
out.append_display_data(YouTubeVideo('WlCKv49Pkvg'))
out
# Out:
# Output(layout=Layout(border='3px solid black'), outputs=({'output_type': 'stream', 'name': 'stdout', 'text': '…
