# %% [markdown]
# # Full Stack Developer from 0 to Big Data - practical cource
#
# *Dataminig - How to search and process data ~~not cryptho (btc)~~*
# <font color=red>(approx 300h)</font> + 1500hrs practical
# ---
# ## what we are learn and research:
#
# ***languages etc.:***
# > **markup/markupdown languages (html,xml,md)**
# > - html
# > - css
# > - ...
#
# > **javascript**
# > - native
# > - frameworks
# > - - bootstrap
# > - - nodejs
# > - - ...
#
# > **php**
# > - native
# > - cms
# > - - Prestashop
# > - - Wordpress
# > - frameworks
# > - - Symfony
# > - - ...
#
# > **db**
# > - **sql**
# > - - python-sql
# > - - php-sql
# > - - ...
# > -**nosql**
# > - - json and
# > - - another non sql formats
#
# > **python**
# > - pep8 & python zen
# > - pandas
# > - numpy
# > - selenium
#
# > **google script (gs)**
#
# > **microsoft powershell (ps)**
#
# > **command line's**
# > - **bash**
# > - **curl**
# > - **microsoft cmd/powershell**
#
# ***IDE and helpful software:***
# - VSCode
# - MS Visual Studio
# - Dbeaver
# - Anaconda
# - - Jupiter and
# - - Ipython
# - XAMPP
# -  helpfull soft (non commercial):
# - - Inkscape
# - - diagrams.net (draw.io)
# - - Gimp
# - - phpMyadmin
# - - Filezillla
# - - SSHClient
# - - Wireshark
# - - Helpful extentions and apps for Chrome, Mozillla, Edge
# - - pygame.org
#
#
# ***Technologies:***
#
# > Hosting principal
# > - http/ftp/sql/mail servers
# > - how WWW works
#
# > client-server protocols
# > - http / https
# > - ftp / sftp
# > - api
# > - ssh
# > - telegram
#
# > sql server (MaryaDb, MySql) dev only. (w.o. administration)
#
#
# > on client ***(forntend)***:
# > - UI minimal design (web & desktop)
# > - cms themes (WordPress, Prestashop) an modules design
# > - Bootstrap
# > - Nodejs
# > - Ipython
# > - Qt (TKinter)
#
# > on server ***(backend)***:
# > - API
# > - Django
# > - CMS:
# > - - Wordpress
# > - - Prestashop
# > - nodeJS
# > - php
# > - phpmyadmin
# > - google colab
# > - google workspace
#
# > site scrapping
#
# > git
# > - github
# > - gitlab.com
# > - gitbooks.io
#
# > Heroku deployment
#
# > Google research
# > - google tables
# > - google colab
# > - google disk
# > - google analytics
# > - Google IAM
#
# > - Amazon AWS
# > - Alibaba Cloud
# > - Google Cloud
#
# > dataminig (NOT cryptho)
# > - neural netwoks
# > - learning AI
#
# ***Copmuter science:***
# - How computer works
# - How OS works
# - Algorythms
# - Boolean algebra
# - How programms works
#
# ***Introducтion to robotics:***
# > Microcontrollers
# > - principle
# > - boards
# > - controllers
# > - - types
# > - - programming
#
#
#  and many, many other interesting things...
# ---

# %%
                                            #########################################################
    
#                                                Эта ячейка запускается на выполнение (CTRL+ENTER)
    
                                            #########################################################

from ipywidgets import Button 
next_url = "Documents/repos/full-stack-develeper-cource.git/0 Подготовительные материалы/"

# Создаем кнопку с нужными параметрами
button1 = Button(description="Далее", 
                        button_style='success' # 'success', 'info', 'warning', 'danger', ''
                        )



def on_button_clicked(b): # Описываем обработчик события
    window.open(next_url)

button1.on_click(on_button_clicked) # Назначаем этот обработчик на событие "on_click"

display(button1) # Отображаем кнопку
# Out:
# Button(button_style='success', description='Далее', style=ButtonStyle())
